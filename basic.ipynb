# %%
with open("C:/Users/jackl/Desktop/python/hello.txt",'r') as reader:
    print(reader.read())
# Out:
# hello world

# %%
with open("C:/Users/jackl/Desktop/python/hello1.txt",'w') as writer
        writer("hello world")

# %%
with open("C:/Users/jackl/Desktop/python/hello1.txt",'r') as reader:
        print(reader.read())
# Out:
# hello world

# %%
fruits = ["apple", "banana", "cherry"]
with open("C:/Users/jackl/Desktop/python/hello1.txt",'w') as writer:
        for x in fruits:
          writer.write(x+"\n")

# %%
fruits = ["apple", "banana", "cherry"]
with open("C:/Users/jackl/Desktop/python/hello1.txt",'w') as writer:
        for x in fruits:
            writer.write(x+"\n")
        for a in range(100):
            writer.write(str(a))
            writer.write("\n")

# %%
with open("C:/Users/jackl/Desktop/python/hello1.txt",'r') as reader:
        print(reader.read())
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-19-df6ddbe85c49> in <module>
#       1 with open("C:/Users/jackl/Desktop/python/hello1.txt",'w') as reader:
# ----> 2         print(reader.read())
#
# UnsupportedOperation: not readable

# %%
msg="hello from Head First Python 2e"
print(id(msg))
print(id(msg))
# Out:
# 1782928864080
# 1782928864080

# %%
a=2+3j
type(a)
b=a*a
print(b)
# Out:
# (-5+12j)

# %%
try:
  f = open("test.txt", 'r')
  data = f.read()
  print("Trying")
except:
  print("Fiddlesticks! Failed")
finally:
  print("Finally!")
  print("All Done")
# Out:
# Fiddlesticks! Failed
# Finally!
# All Done

# %%
fruits = ["apple", "banana", "cherry"]

try:
    f = open("C:/Users/jackl/Desktop/python/hello2.txt", 'wb')
except OSError:
    print("Could not open/read file:")
    sys.exit()

    with f as writer:
        for x in fruits:
            writer.write(x+"\n")
        for a in range(100):
            writer.write(str(a))
            writer.write("\n")
finally:
    print("\n")

# %%
import ctypes
a = 5
address = id(a)
address
ctypes.cast(address, ctypes.py_object).value
# Out:
# 5

# %%
print(0x10)
# Out:
# 16

# %%
print(0o10)
# Out:
# 8

# %%
print(0b10)
# Out:
# 2

# %%
1.79e308
# Out:
# 1.79e+308

# %%
a=1.9e308

# %%
5e-324
# Out:
# 5e-324

# %%
1e-325
# Out:
# 0.0

# %%
type(a)
# Out:
# float

# %%
...
# Out:
# Ellipsis

# %%
print('a\
... b\
... c')
# Out:
# abc

# %%
print('foo\\bar')
# Out:
# foo\bar

# %%
print('foo\tbar')
# Out:
# foo	bar

# %%
type(True)
# Out:
# bool

# %%
class MyClass(object):
    class_var = 1

    def __init__(self, i_var):
        self.i_var = i_var

# %%
foo = MyClass(2)
bar = MyClass(3)

foo.class_var, foo.i_var
# Out:
# (1, 2)

# %%
bar.class_var, bar.i_var
# Out:
# (1, 3)

# %%
MyClass.class_var
# Out:
# 1

# %%
class MyClass(object):
    ## No need for dot syntax
    class_var = 1

    def __init__(self, i_var):
        self.i_var = i_var

# %%
class Service(object):
    data = []

    def __init__(self, other_data):
        self.other_data = other_data

# %%
s1 = Service(['a', 'b'])
s2 = Service(['c', 'd'])

# %%
s1.data.append(1)

s1.data
# Out:
# [1]

# %%
s1.other_data
# Out:
# ['a', 'b']

# %%
s2.data
# Out:
# [1]

# %%
s2.data.append(2)

# %%
s1.data
# Out:
# [1, 2]

# %%
s2.data
# Out:
# [1, 2]

# %%
class Circle(object):
    pi = 3.14159

    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return Circle.pi * self.radius * self.radius

# %%
Circle.pi
# Out:
# 3.14159

# %%
class MyClass(object):
    limit = 10

    def __init__(self):
        self.data = []

    def item(self, i):
        return self.data[i]

    def add(self, e):
        if len(self.data) >= self.limit:
            raise Exception("Too many elements")
        self.data.append(e)

# %%
MyClass.limit
# Out:
# 10

# %%
class Person(object):
    all_names = []

    def __init__(self, name):
        self.name = name
        Person.all_names.append(name)

joe = Person('Joe')
bob = Person('Bob')
print(Person.all_names)
# Out:
# ['Joe', 'Bob']

# %%
class Person(object):
    all_people = []

    def __init__(self, name):
        self.name = name
        Person.all_people.append(self)

joe = Person('Joe')
bob = Person('Bob')
print(Person.all_people)
# Out:
# [<__main__.Person object at 0x0000019F1ED9E7F0>, <__main__.Person object at 0x0000019F1ED9E460>]

# %%
def called_class():
    print("Class assignment")
    return 2

class Bar(object):
    y = called_class()

    def __init__(self, x):
        self.x = x

## "Class assignment"

def called_instance():
    print("Instance assignment")
    return 2

class Foo(object):
    def __init__(self, x):
        self.y = called_instance()
        self.x = x

Bar(1)
Bar(2)
Foo(1)
## "Instance assignment"
Foo(2)
## "Instance assignment"
# Out:
# Class assignment
# Instance assignment
# Instance assignment

# %%
import dis

class Bar(object):
    y = 2

    def __init__(self, x):
        self.x = x

class Foo(object):
    def __init__(self, x):
        self.y = 2
        self.x = x

dis.dis(Bar)
dis.dis(Foo)
# Out:
# Disassembly of __init__:
#   7           0 LOAD_FAST                1 (x)
#               2 LOAD_FAST                0 (self)
#               4 STORE_ATTR               0 (x)
#               6 LOAD_CONST               0 (None)
#               8 RETURN_VALUE
#
# Disassembly of __init__:
#  11           0 LOAD_CONST               1 (2)
#               2 LOAD_FAST                0 (self)
#               4 STORE_ATTR               0 (y)
#
#  12           6 LOAD_FAST                1 (x)
#               8 LOAD_FAST                0 (self)
#              10 STORE_ATTR               1 (x)
#              12 LOAD_CONST               0 (None)
#              14 RETURN_VALUE

# %%
#import timeit


from timeit import default_timer as timer

start = timer()
i=0
for i in range(10000):
    Bar(2)
end = timer()
print(end - start)
# Out:
# 0.0022332000007736497

# %%
import matplotlib.pyplot as plt
import numpy as np
import math as math
fig, _ = plt.subplots()
type(fig)
a=np.arange(50)/50
len(a)
b=np.sin(2*math.pi*a)
plt.plot(a,b)


x = np.arange(0,4*np.pi,0.1)   # start,stop,step
y = np.sin(x)

plt.plot(x,y)

# %%
import math
import matplotlib.pyplot as plt 
  
in_array = [-3.14159265, -2.57039399, -0.28559933,
            0.28559933, 2.57039399,  3.14159265]
  
out_array = []
  
for i in range(len(in_array)):
    out_array.append(math.sin(in_array[i]))
    i += 1
  
   
print("in_array : ", in_array) 
print("\nout_array : ", out_array) 
  
# red for numpy.sin() 
plt.plot(in_array, out_array, color = 'red', marker = "o") 
plt.title("math.sin()") 
plt.xlabel("X") 
plt.ylabel("Y") 
plt.show()
# Out:
# in_array :  [-3.14159265, -2.57039399, -0.28559933, 0.28559933, 2.57039399, 3.14159265]
#
# out_array :  [-3.5897930298416118e-09, -0.5406408168673427, -0.2817325547837714, 0.2817325547837714, 0.5406408168673427, 3.5897930298416118e-09]

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints)
plt.xlabel('Time')
plt.ylabel('value')
plt.savefig('C:/Users/jackl/Desktop/python/books_read.png')
plt.show()

# %%
import pandas as pd
#import plotly.express as px
import matplotlib.pyplot as plt

df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2014_apple_stock.csv')

print(df.head(10))
x=df.AAPL_x
y=df.AAPL_y
plt.title("Apple Stock")
plt.xlabel('Time')
plt.ylabel('value')
fig = plt.plot(x, y)
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
fig.savefig('test2png.png', dpi=200)
# Out:
#        AAPL_x     AAPL_y
# 0  2014-01-02  77.445395
# 1  2014-01-03  77.045575
# 2  2014-01-06  74.896972
# 3  2014-01-07  75.856461
# 4  2014-01-08  75.091947
# 5  2014-01-09  76.202632
# 6  2014-01-10  75.230184
# 7  2014-01-13  73.848918
# 8  2014-01-14  75.011353
# 9  2014-01-15  77.144814

# %%
import pandas as pd
#import plotly.express as px
import matplotlib.pyplot as plt

df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2014_apple_stock.csv')

print(df.head(10))
x=df.AAPL_x
y=df.AAPL_y
plt.title("Apple Stock")
plt.xlabel('Time')
plt.ylabel('value')
plt.rcParams["figure.figsize"] = (20,3)
plt.xticks(np.arange(0, len(x)+1, 1.0))
fig = plt.plot(x, y)
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
fig.savefig('stock.png', dpi=200)
# Out:
#        AAPL_x     AAPL_y
# 0  2014-01-02  77.445395
# 1  2014-01-03  77.045575
# 2  2014-01-06  74.896972
# 3  2014-01-07  75.856461
# 4  2014-01-08  75.091947
# 5  2014-01-09  76.202632
# 6  2014-01-10  75.230184
# 7  2014-01-13  73.848918
# 8  2014-01-14  75.011353
# 9  2014-01-15  77.144814

# %%
import pandas as pd
import matplotlib.pyplot as plt
dataframe = pd.read_csv("C:/Users/jackl/Desktop/python/scottish_hills.csv")
print(dataframe.head(10))
x = dataframe.Height
y = dataframe.Latitude
plt.plot(x,y)
# Out:
#                     Hill Name  Height   Latitude  Longitude    Osgrid
# 0       A' Bhuidheanach Bheag   936.0  56.870342  -4.199001  NN660775
# 1               A' Chailleach   997.0  57.693800  -5.128715  NH136714
# 2               A' Chailleach   929.2  57.109564  -4.179285  NH681041
# 3  A' Chraileag (A' Chralaig)  1120.0  57.184186  -5.154837  NH094147
# 4             A' Ghlas-bheinn   918.0  57.255090  -5.303687  NH008231
# 5               A' Mhaighdean   967.0  57.719644  -5.346720  NH007749
# 6              A' Mharconaich   973.2  56.857002  -4.290668  NN604762
# 7                  Am Basteir   934.0  57.247931  -6.202982  NG465253
# 8                   Am Bodach  1031.8  56.741727  -4.983393  NN176650
# 9               Am Faochagach   953.0  57.771801  -4.853899  NH303793
